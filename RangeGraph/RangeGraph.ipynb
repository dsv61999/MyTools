# %%
import seaborn as sns; sns.set()
import pandas as pd

# %%
df_imagenet = pd.read_csv('data/imagenet_mAP.csv')
df_coco2017 = pd.read_csv('data/coco2017_mAP.csv')

# %%
df_imagenet.head(5)
# Out:
#    index  convolution layer     mAP pre-trained task
# 0      0                  0  0.6501         ImageNet
# 1      1                  5  0.6658         ImageNet
# 2      2                 10  0.6647         ImageNet
# 3      3                 15  0.6766         ImageNet
# 4      4                 20  0.6873         ImageNet

# %%
df_coco2017.head(5)
# Out:
#    index  convolution layer     mAP pre-trained task
# 0      0                  0  0.5701         COCO2017
# 1      1                  5  0.6301         COCO2017
# 2      2                 10  0.6674         COCO2017
# 3      3                 15  0.6729         COCO2017
# 4      4                 20  0.6689         COCO2017

# %%
plot = sns.lineplot(x="convolution layer", y="mAP", data=df_imagenet)

# %%
plot = sns.lineplot(x="convolution layer", y="mAP", hue="pre-trained task",data=df_coco2017)

# %%
df_difference = pd.read_csv("mAP.csv")
df_difference.head(5)
# Out:
#    index  convolution layer     mAP pre-trained task
# 0      0                  0  0.6501         ImageNet
# 1      1                  5  0.6658         ImageNet
# 2      2                 10  0.6647         ImageNet
# 3      3                 15  0.6766         ImageNet
# 4      4                 20  0.6873         ImageNet

# %%
plot = sns.lineplot(x="convolution layer", y="mAP", hue="pre-trained task",data=df_difference)

# %%
figure = plot.get_figure()
figure.savefig("mAP.png")
